# %%
import pandas as pd
import numpy as np
import os

# Đường dẫn đến file parquet (từ thư mục dự án)
# Giả sử cấu trúc như mày mô tả: E:\taxi-project\data\yellow_tripdata_2023-01.parquet
# Và notebook đang ở trong E:\taxi-project\taxi-demand-prediction\
# Nên đường dẫn tương đối: "../data/yellow_tripdata_2023-01.parquet"

file_path = "../data/yellow_tripdata_2023-01.parquet"

# Kiểm tra file có tồn tại không
if os.path.exists(file_path):
    print("Tìm thấy file tại:", os.path.abspath(file_path))
else:
    print("Không tìm thấy file. Hãy kiểm tra lại đường dẫn.")
# Out:
# Tìm thấy file tại: e:\taxi-project\data\yellow_tripdata_2023-01.parquet

# %%
df = pd.read_parquet(file_path)
print("Đã đọc xong file. Kích thước:", df.shape)
# Out:
# Đã đọc xong file. Kích thước: (3066766, 19)

# %%
# 5 dòng đầu
df.head()

# Thông tin tổng quan
df.info()

# Thống kê số lượng null (mày đã làm)
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# ...

# %%
df_sample = pd.read_parquet(file_path, engine='pyarrow', columns=None, filters=None)
# Nhưng read_parquet không hỗ trợ trực tiếp nrows. Có thể đọc toàn bộ rồi lấy sample.
# Hoặc dùng pyarrow.parquet để đọc từng nhóm dòng.

# %%
# Xem chi tiết dòng đầu tiên
df.iloc[0]
# Out:
# VendorID                                   2
# tpep_pickup_datetime     2023-01-01 00:32:10
# tpep_dropoff_datetime    2023-01-01 00:40:36
# passenger_count                          1.0
# trip_distance                           0.97
# RatecodeID                               1.0
# store_and_fwd_flag                         N
# PULocationID                             161
# DOLocationID                             141
# payment_type                               2
# fare_amount                              9.3
# extra                                    1.0
# mta_tax                                  0.5
# tip_amount                               0.0
# tolls_amount                             0.0
# improvement_surcharge                    1.0
# total_amount                            14.3
# congestion_surcharge                     2.5
# airport_fee                              0.0
# Name: 0, dtype: object

# %%
df[['tpep_pickup_datetime', 'passenger_count', 'trip_distance', 'total_amount']].iloc[0]
# Out:
# tpep_pickup_datetime    2023-01-01 00:32:10
# passenger_count                         1.0
# trip_distance                          0.97
# total_amount                           14.3
# Name: 0, dtype: object

# %%
df.sample(1)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1199368         2  2023-01-13 23:59:09   2023-01-14 00:02:36              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 1199368           1.05         1.0                  N           237
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 1199368           236             1          6.5    1.0      0.5         1.0
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 1199368           0.0                    1.0          12.5
#
#          congestion_surcharge  airport_fee
# 1199368                   2.5          0.0

# %%
df.iloc[-1]
# Out:
# VendorID                                   2
# tpep_pickup_datetime     2023-01-31 23:07:32
# tpep_dropoff_datetime    2023-01-31 23:21:56
# passenger_count                          NaN
# trip_distance                           2.85
# RatecodeID                               NaN
# store_and_fwd_flag                      None
# PULocationID                             262
# DOLocationID                             143
# payment_type                               0
# fare_amount                            15.97
# extra                                    0.0
# mta_tax                                  0.5
# tip_amount                               2.0
# tolls_amount                             0.0
# improvement_surcharge                    1.0
# total_amount                           21.97
# congestion_surcharge                     NaN
# airport_fee                              NaN
# Name: 3066765, dtype: object
